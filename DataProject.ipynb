# %%
import pandas as pd
import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
location='C:/Users/woogu/Python/DataIncubator/temp_datalab_records_linkedin_company.csv'

# %%
df=pd.read_csv(location)
# Out:
# C:\Users\woogu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['dataset_id', 'as_of_date', 'company_name', 'followers_count',
#        'employees_on_platform', 'link', 'industry', 'date_added',
#        'date_updated', 'description', 'website', 'entity_id', 'cusip', 'isin'],
#       dtype='object')

# %%
df.head()
# Out:
#    dataset_id  as_of_date            company_name  followers_count  \
# 0       58329  2015-09-14           Goldman Sachs           552254
# 1       58329  2015-09-15           Goldman Sachs           552862
# 2       58363  2015-09-16     United Technologies            59157
# 3       58366  2015-09-16            Novo Nordisk           336175
# 4       58371  2015-09-16  Lowe's Companies, Inc.           134255
#
#    employees_on_platform                                   link  \
# 0                  38124  https://www.linkedin.com/company/1382
# 1                  38141  https://www.linkedin.com/company/1382
# 2                  14982  https://www.linkedin.com/company/2426
# 3                  26448  https://www.linkedin.com/company/2227
# 4                  62574  https://www.linkedin.com/company/4128
#
#                industry              date_added            date_updated  \
# 0    Investment Banking  2015-09-14 00:00:00+00  2015-09-14 00:00:00+00
# ...

# %%
#finding 10 companies with the most postings
posting=df.loc[:,'company_name'].tolist()

# %%
def unique(list1):
    uniquelist=[]
    for  l in list1:
        if l not in uniquelist:
            uniquelist.append(l)
    return uniquelist
comp_name=unique(posting)

# %%
comp_name
# Out:
# ['Goldman Sachs',
#  'United Technologies',
#  'Novo Nordisk',
#  "Lowe's Companies, Inc.",
#  'UnitedHealth Group',
#  'McKesson',
#  'BBVA',
#  'IBM',
#  'MasterCard',
#  'Sanofi',
#  'Novartis',
#  'Cisco',
#  'GE',
#  'RBC',
#  'Priceline.com',
#  'Philip Morris International',
#  'Intel Corporation',
#  'ConocoPhillips',
#  'TJ Maxx',
#  'Ford Motor Company',
#  'The Walt Disney Company',
#  'Procter & Gamble',
#  'BHP Billiton',
#  "McDonald's Corporation",
#  'Amazon',
#  'Banco Santander',
#  'The Dow Chemical Company',
#  'Apple',
#  'TOTAL',
#  'HSBC',
#  '3M',
#  'Simon Property Group',
#  'Google',
#  'Honeywell',
#  'Toyota Motor Corporation',
#  'Visa',
#  'Walmart',
#  'Texas Instruments',
#  'Duke Energy Corporation',
#  'Biogen',
#  'Chevron',
#  'Hewlett-Packard',
#  'Eli Lilly and Company',
#  'Oracle',
#  'Teva Pharmaceuticals',
#  'Morgan Stanley',
#  'Ambev',
#  'U.S. Bank',
#  'Starbucks',
#  'Anheuser-Busch InBev',
#  'BlackRock',
#  'Citi',
# ...

# %%
num_posting=[0]*len(comp_name)#create a list of 0s with length of number of company name
for i in range(len(df)):# for all collisions in 2016 with zip code information
    b=unique_zip.index(df16_nonan.loc[i,'ZIP CODE'])#get index of the zip code for the collision
    collision_zip[b]+=df16_nonan.loc[i,'TotalV']#add number of vehicles invloved in each collision

# %%
num_posting=[0]*len(comp_name)
for i in range(len(comp_name)):
    num_posting[i]=len(df.loc[df['company_name']==comp_name[i]])

# %%
posting=list(zip(comp_name,num_posting))

# %%
posting
# Out:
# [('Goldman Sachs', 1022),
#  ('United Technologies', 1015),
#  ('Novo Nordisk', 1018),
#  ("Lowe's Companies, Inc.", 1019),
#  ('UnitedHealth Group', 1015),
#  ('McKesson', 1018),
#  ('BBVA', 1019),
#  ('IBM', 1018),
#  ('MasterCard', 295),
#  ('Sanofi', 1015),
#  ('Novartis', 1017),
#  ('Cisco', 1024),
#  ('GE', 1020),
#  ('RBC', 1015),
#  ('Priceline.com', 1022),
#  ('Philip Morris International', 1016),
#  ('Intel Corporation', 1022),
#  ('ConocoPhillips', 1019),
#  ('TJ Maxx', 1015),
#  ('Ford Motor Company', 1021),
#  ('The Walt Disney Company', 1020),
#  ('Procter & Gamble', 930),
#  ('BHP Billiton', 604),
#  ("McDonald's Corporation", 187),
#  ('Amazon', 1023),
#  ('Banco Santander', 1015),
#  ('The Dow Chemical Company', 1021),
#  ('Apple', 1025),
#  ('TOTAL', 69),
#  ('HSBC', 1019),
#  ('3M', 1017),
#  ('Simon Property Group', 1015),
#  ('Google', 1022),
#  ('Honeywell', 1020),
#  ('Toyota Motor Corporation', 1015),
#  ('Visa', 1015),
#  ('Walmart', 1012),
# ...

# %%
def sortSecond(val): 
    return val[1]
posting.sort(key=sortSecond,reverse=True)

# %%
posting
# Out:
# [('City National Bank', 1605),
#  ('American Airlines', 1029),
#  ('Apple', 1025),
#  ('Cisco', 1024),
#  ('Activision', 1024),
#  ('Amgen', 1024),
#  ('Amazon', 1023),
#  ('Biogen', 1023),
#  ('Comcast', 1023),
#  ('Microsoft', 1023),
#  ('Facebook', 1023),
#  ('ADP', 1023),
#  ('Illumina', 1023),
#  ('Goldman Sachs', 1022),
#  ('Priceline.com', 1022),
#  ('Intel Corporation', 1022),
#  ('Google', 1022),
#  ('Starbucks', 1022),
#  ('Gilead Sciences', 1022),
#  ('Celgene', 1022),
#  ('Mylan', 1022),
#  ('Qualcomm', 1022),
#  ('DIRECTV', 1022),
#  ('Cognizant', 1022),
#  ('Alexion Pharmaceuticals, Inc.', 1022),
#  ('Avago Technologies', 1022),
#  ('Ericsson', 1022),
#  ('Adobe', 1022),
#  ('IAC', 1022),
#  ('Avis Budget Group', 1022),
#  ('The Habit Burger Grill', 1022),
#  ('Intuit', 1022),
#  ('Ctrip.com', 1022),
#  ('Ford Motor Company', 1021),
#  ('The Dow Chemical Company', 1021),
#  ('Texas Instruments', 1021),
#  ('Vodafone', 1021),
#  ('Costco Wholesale', 1021),
# ...

# %%
Top20=posting[0:20]
Top20
# Out:
# [('City National Bank', 1605),
#  ('American Airlines', 1029),
#  ('Apple', 1025),
#  ('Cisco', 1024),
#  ('Activision', 1024),
#  ('Amgen', 1024),
#  ('Amazon', 1023),
#  ('Biogen', 1023),
#  ('Comcast', 1023),
#  ('Microsoft', 1023),
#  ('Facebook', 1023),
#  ('ADP', 1023),
#  ('Illumina', 1023),
#  ('Goldman Sachs', 1022),
#  ('Priceline.com', 1022),
#  ('Intel Corporation', 1022),
#  ('Google', 1022),
#  ('Starbucks', 1022),
#  ('Gilead Sciences', 1022),
#  ('Celgene', 1022)]

# %%
city=df.loc[df['company_name']=='City National Bank']

# %%
city
# Out:
#          dataset_id  as_of_date        company_name  followers_count  \
# 2060          59148  2015-09-21  City National Bank            10831
# 2560          59148  2015-09-22  City National Bank            10840
# 3075          59148  2015-09-23  City National Bank            10848
# 3607          59148  2015-09-24  City National Bank            10858
# 4140          59148  2015-09-25  City National Bank            10868
# 4679          59148  2015-09-26  City National Bank            10880
# 5218          59148  2015-09-27  City National Bank            10883
# 5758          59148  2015-09-28  City National Bank            10896
# 6297          59148  2015-09-29  City National Bank            10901
# 6839          59148  2015-09-30  City National Bank            10906
# 7383          59148  2015-10-01  City National Bank            10912
# 7927          59148  2015-10-02  City National Bank            10922
# 8471          59148  2015-10-03  City National Bank            10921
# ...

# %%
emp=city['employees_on_platform'].tolist()
date=city['as_of_date'].tolist()
fol=city['followers_count'].tolist()
employee={'x':date,'y':emp,''}
trace0=go.Scatter(x=date,y=emp,mode='markers',name='employees')
followers={'x':date,'y':fol,'type':'bar'}
trace1=go.Scatter(x=date,y=fol,mode='markers',name='followers')

# %%
plotly.offline.iplot([employee, followers])
# Out:
# <div>
#
#
#             <div id="f846f56f-1dbc-485f-8260-672788d5dc83" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f846f56f-1dbc-485f-8260-672788d5dc83")) {
#                     Plotly.newPlot(
#                         'f846f56f-1dbc-485f-8260-672788d5dc83',
# ...
